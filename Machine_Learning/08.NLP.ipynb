# %%
# !conda update conda
# !pip install --upgrade pip
# !pip install konlpy
# !pip install tweepy==3.10.0
# !conda install -y -c conda-forge jpype1==1.0.2
# !conda install -y -c conda-forge wordcloud
# !conda install -y nltk
# !conda install -y scikit-learn
# Out:
# Collecting package metadata (current_repodata.json): ...working... failed
# WARNING conda.exceptions:print_unexpected_error_report(1251): KeyError('pkgs_dirs')
# Traceback (most recent call last):
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\exceptions.py", line 1129, in __call__
#     return func(*args, **kwargs)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main.py", line 86, in main_subshell
#     exit_code = do_call(args, p)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\conda_argparse.py", line 93, in do_call
#     return getattr(module, func_name)(args, parser)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\notices\core.py", line 72, in wrapper
#     return_value = func(*args, **kwargs)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main_update.py", line 22, in execute
#     install(args, parser, 'update')
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\install.py", line 261, in install
#     unlink_link_transaction = solver.solve_for_transaction(
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 156, in solve_for_transaction
#     unlink_precs, link_precs = self.solve_for_diff(update_modifier, deps_modifier,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 199, in solve_for_diff
#     final_precs = self.solve_final_state(update_modifier, deps_modifier, prune, ignore_pinned,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 304, in solve_final_state
#     ssc = self._collect_all_metadata(ssc)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\common\io.py", line 86, in decorated
#     return f(*args, **kwds)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 467, in _collect_all_metadata
#     index, r = self._prepare(prepared_specs)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 1061, in _prepare
#     reduced_index = get_reduced_index(self.prefix, self.channels,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\index.py", line 301, in get_reduced_index
#     new_records = SubdirData.query_all(spec, channels=channels, subdirs=subdirs,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 115, in query_all
#     create_cache_dir()
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 737, in create_cache_dir
#     cache_dir = join(PackageCacheData.first_writable().pkgs_dir, 'cache')
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\package_cache_data.py", line 158, in first_writable
#     pkgs_dirs = context.pkgs_dirs
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\base\context.py", line 555, in pkgs_dirs
#     fixed_dirs += user_data_dir(APP_NAME, APP_NAME),
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 67, in user_data_dir
#     path = os.path.join(_get_win_folder(const), appauthor, appname)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 265, in _get_win_folder_with_pywin32
#     from win32com.shell import shellcon, shell
# ImportError: DLL load failed while importing shell: 지정된 프로시저를 찾을 수 없습니다.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\exceptions.py", line 1249, in print_unexpected_error_report
#     message_builder.append(get_main_info_str(error_report['conda_info']))
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main_info.py", line 237, in get_main_info_str
#     info_dict['_' + key] = ('\n' + 26 * ' ').join(info_dict[key])
# KeyError: 'pkgs_dirs'
#
# # >>>>>>>>>>>>>>>>>>>>>> ERROR REPORT <<<<<<<<<<<<<<<<<<<<<<
#
#     Traceback (most recent call last):
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\exceptions.py", line 1129, in __call__
#         return func(*args, **kwargs)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main.py", line 86, in main_subshell
#         exit_code = do_call(args, p)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\conda_argparse.py", line 93, in do_call
#         return getattr(module, func_name)(args, parser)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\notices\core.py", line 72, in wrapper
#         return_value = func(*args, **kwargs)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main_update.py", line 22, in execute
#         install(args, parser, 'update')
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\install.py", line 261, in install
#         unlink_link_transaction = solver.solve_for_transaction(
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 156, in solve_for_transaction
#         unlink_precs, link_precs = self.solve_for_diff(update_modifier, deps_modifier,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 199, in solve_for_diff
#         final_precs = self.solve_final_state(update_modifier, deps_modifier, prune, ignore_pinned,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 304, in solve_final_state
#         ssc = self._collect_all_metadata(ssc)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\common\io.py", line 86, in decorated
#         return f(*args, **kwds)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 467, in _collect_all_metadata
#         index, r = self._prepare(prepared_specs)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 1061, in _prepare
#         reduced_index = get_reduced_index(self.prefix, self.channels,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\index.py", line 301, in get_reduced_index
#         new_records = SubdirData.query_all(spec, channels=channels, subdirs=subdirs,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 115, in query_all
#         create_cache_dir()
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 737, in create_cache_dir
#         cache_dir = join(PackageCacheData.first_writable().pkgs_dir, 'cache')
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\package_cache_data.py", line 158, in first_writable
#         pkgs_dirs = context.pkgs_dirs
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\base\context.py", line 555, in pkgs_dirs
#         fixed_dirs += user_data_dir(APP_NAME, APP_NAME),
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 67, in user_data_dir
#         path = os.path.join(_get_win_folder(const), appauthor, appname)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 265, in _get_win_folder_with_pywin32
#         from win32com.shell import shellcon, shell
#     ImportError: DLL load failed while importing shell: 지정된 프로시저를 찾을 수 없습니다.
#
# `$ c:\Users\qnwje\anaconda3\Scripts\conda-script.py update conda`
#
#   environment variables:
# conda info could not be constructed.
# KeyError('pkgs_dirs')
#
# An unexpected error has occurred. Conda has prepared the above report.
# Requirement already satisfied: pip in c:\users\qnwje\anaconda3\lib\site-packages (22.2.2)
# Collecting pip
#   Using cached pip-23.3.1-py3-none-any.whl (2.1 MB)
# ERROR: To modify pip, please run the following command:
# c:\Users\qnwje\anaconda3\python.exe -m pip install --upgrade pip
# Requirement already satisfied: konlpy in c:\users\qnwje\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: numpy>=1.6 in c:\users\qnwje\anaconda3\lib\site-packages (from konlpy) (1.21.5)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\qnwje\anaconda3\lib\site-packages (from konlpy) (4.9.1)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\qnwje\anaconda3\lib\site-packages (from konlpy) (1.4.1)
# Requirement already satisfied: packaging in c:\users\qnwje\appdata\roaming\python\python39\site-packages (from JPype1>=0.7.0->konlpy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\qnwje\appdata\roaming\python\python39\site-packages (from packaging->JPype1>=0.7.0->konlpy) (3.0.9)
# Requirement already satisfied: tweepy==3.10.0 in c:\users\qnwje\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\qnwje\anaconda3\lib\site-packages (from tweepy==3.10.0) (2.28.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\qnwje\anaconda3\lib\site-packages (from tweepy==3.10.0) (1.3.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\qnwje\appdata\roaming\python\python39\site-packages (from tweepy==3.10.0) (1.16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\qnwje\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy==3.10.0) (3.2.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\qnwje\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\qnwje\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\qnwje\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\qnwje\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (3.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\qnwje\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (1.7.1)
# Collecting package metadata (current_repodata.json): ...working... failed
# WARNING conda.exceptions:print_unexpected_error_report(1251): KeyError('pkgs_dirs')
# Traceback (most recent call last):
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\exceptions.py", line 1129, in __call__
#     return func(*args, **kwargs)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main.py", line 86, in main_subshell
#     exit_code = do_call(args, p)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\conda_argparse.py", line 93, in do_call
#     return getattr(module, func_name)(args, parser)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\notices\core.py", line 72, in wrapper
#     return_value = func(*args, **kwargs)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main_install.py", line 22, in execute
#     install(args, parser, 'install')
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\install.py", line 261, in install
#     unlink_link_transaction = solver.solve_for_transaction(
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 156, in solve_for_transaction
#     unlink_precs, link_precs = self.solve_for_diff(update_modifier, deps_modifier,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 199, in solve_for_diff
#     final_precs = self.solve_final_state(update_modifier, deps_modifier, prune, ignore_pinned,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 304, in solve_final_state
#     ssc = self._collect_all_metadata(ssc)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\common\io.py", line 86, in decorated
#     return f(*args, **kwds)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 467, in _collect_all_metadata
#     index, r = self._prepare(prepared_specs)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 1061, in _prepare
#     reduced_index = get_reduced_index(self.prefix, self.channels,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\index.py", line 301, in get_reduced_index
#     new_records = SubdirData.query_all(spec, channels=channels, subdirs=subdirs,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 115, in query_all
#     create_cache_dir()
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 737, in create_cache_dir
#     cache_dir = join(PackageCacheData.first_writable().pkgs_dir, 'cache')
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\package_cache_data.py", line 158, in first_writable
#     pkgs_dirs = context.pkgs_dirs
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\base\context.py", line 555, in pkgs_dirs
#     fixed_dirs += user_data_dir(APP_NAME, APP_NAME),
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 67, in user_data_dir
#     path = os.path.join(_get_win_folder(const), appauthor, appname)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 265, in _get_win_folder_with_pywin32
#     from win32com.shell import shellcon, shell
# ImportError: DLL load failed while importing shell: 지정된 프로시저를 찾을 수 없습니다.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\exceptions.py", line 1249, in print_unexpected_error_report
#     message_builder.append(get_main_info_str(error_report['conda_info']))
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main_info.py", line 237, in get_main_info_str
#     info_dict['_' + key] = ('\n' + 26 * ' ').join(info_dict[key])
# KeyError: 'pkgs_dirs'
#
# # >>>>>>>>>>>>>>>>>>>>>> ERROR REPORT <<<<<<<<<<<<<<<<<<<<<<
#
#     Traceback (most recent call last):
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\exceptions.py", line 1129, in __call__
#         return func(*args, **kwargs)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main.py", line 86, in main_subshell
#         exit_code = do_call(args, p)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\conda_argparse.py", line 93, in do_call
#         return getattr(module, func_name)(args, parser)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\notices\core.py", line 72, in wrapper
#         return_value = func(*args, **kwargs)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main_install.py", line 22, in execute
#         install(args, parser, 'install')
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\install.py", line 261, in install
#         unlink_link_transaction = solver.solve_for_transaction(
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 156, in solve_for_transaction
#         unlink_precs, link_precs = self.solve_for_diff(update_modifier, deps_modifier,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 199, in solve_for_diff
#         final_precs = self.solve_final_state(update_modifier, deps_modifier, prune, ignore_pinned,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 304, in solve_final_state
#         ssc = self._collect_all_metadata(ssc)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\common\io.py", line 86, in decorated
#         return f(*args, **kwds)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 467, in _collect_all_metadata
#         index, r = self._prepare(prepared_specs)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 1061, in _prepare
#         reduced_index = get_reduced_index(self.prefix, self.channels,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\index.py", line 301, in get_reduced_index
#         new_records = SubdirData.query_all(spec, channels=channels, subdirs=subdirs,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 115, in query_all
#         create_cache_dir()
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 737, in create_cache_dir
#         cache_dir = join(PackageCacheData.first_writable().pkgs_dir, 'cache')
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\package_cache_data.py", line 158, in first_writable
#         pkgs_dirs = context.pkgs_dirs
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\base\context.py", line 555, in pkgs_dirs
#         fixed_dirs += user_data_dir(APP_NAME, APP_NAME),
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 67, in user_data_dir
#         path = os.path.join(_get_win_folder(const), appauthor, appname)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 265, in _get_win_folder_with_pywin32
#         from win32com.shell import shellcon, shell
#     ImportError: DLL load failed while importing shell: 지정된 프로시저를 찾을 수 없습니다.
#
# `$ c:\Users\qnwje\anaconda3\Scripts\conda-script.py install -y -c conda-forge jpype==1.0.2`
#
#   environment variables:
# conda info could not be constructed.
# KeyError('pkgs_dirs')
#
# An unexpected error has occurred. Conda has prepared the above report.
# Collecting package metadata (current_repodata.json): ...working... failed
# WARNING conda.exceptions:print_unexpected_error_report(1251): KeyError('pkgs_dirs')
# Traceback (most recent call last):
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\exceptions.py", line 1129, in __call__
#     return func(*args, **kwargs)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main.py", line 86, in main_subshell
#     exit_code = do_call(args, p)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\conda_argparse.py", line 93, in do_call
#     return getattr(module, func_name)(args, parser)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\notices\core.py", line 72, in wrapper
#     return_value = func(*args, **kwargs)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main_install.py", line 22, in execute
#     install(args, parser, 'install')
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\install.py", line 261, in install
#     unlink_link_transaction = solver.solve_for_transaction(
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 156, in solve_for_transaction
#     unlink_precs, link_precs = self.solve_for_diff(update_modifier, deps_modifier,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 199, in solve_for_diff
#     final_precs = self.solve_final_state(update_modifier, deps_modifier, prune, ignore_pinned,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 304, in solve_final_state
#     ssc = self._collect_all_metadata(ssc)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\common\io.py", line 86, in decorated
#     return f(*args, **kwds)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 467, in _collect_all_metadata
#     index, r = self._prepare(prepared_specs)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 1061, in _prepare
#     reduced_index = get_reduced_index(self.prefix, self.channels,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\index.py", line 301, in get_reduced_index
#     new_records = SubdirData.query_all(spec, channels=channels, subdirs=subdirs,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 115, in query_all
#     create_cache_dir()
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 737, in create_cache_dir
#     cache_dir = join(PackageCacheData.first_writable().pkgs_dir, 'cache')
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\package_cache_data.py", line 158, in first_writable
#     pkgs_dirs = context.pkgs_dirs
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\base\context.py", line 555, in pkgs_dirs
#     fixed_dirs += user_data_dir(APP_NAME, APP_NAME),
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 67, in user_data_dir
#     path = os.path.join(_get_win_folder(const), appauthor, appname)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 265, in _get_win_folder_with_pywin32
#     from win32com.shell import shellcon, shell
# ImportError: DLL load failed while importing shell: 지정된 프로시저를 찾을 수 없습니다.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\exceptions.py", line 1249, in print_unexpected_error_report
#     message_builder.append(get_main_info_str(error_report['conda_info']))
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main_info.py", line 237, in get_main_info_str
#     info_dict['_' + key] = ('\n' + 26 * ' ').join(info_dict[key])
# KeyError: 'pkgs_dirs'
#
# # >>>>>>>>>>>>>>>>>>>>>> ERROR REPORT <<<<<<<<<<<<<<<<<<<<<<
#
#     Traceback (most recent call last):
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\exceptions.py", line 1129, in __call__
#         return func(*args, **kwargs)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main.py", line 86, in main_subshell
#         exit_code = do_call(args, p)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\conda_argparse.py", line 93, in do_call
#         return getattr(module, func_name)(args, parser)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\notices\core.py", line 72, in wrapper
#         return_value = func(*args, **kwargs)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main_install.py", line 22, in execute
#         install(args, parser, 'install')
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\install.py", line 261, in install
#         unlink_link_transaction = solver.solve_for_transaction(
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 156, in solve_for_transaction
#         unlink_precs, link_precs = self.solve_for_diff(update_modifier, deps_modifier,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 199, in solve_for_diff
#         final_precs = self.solve_final_state(update_modifier, deps_modifier, prune, ignore_pinned,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 304, in solve_final_state
#         ssc = self._collect_all_metadata(ssc)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\common\io.py", line 86, in decorated
#         return f(*args, **kwds)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 467, in _collect_all_metadata
#         index, r = self._prepare(prepared_specs)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 1061, in _prepare
#         reduced_index = get_reduced_index(self.prefix, self.channels,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\index.py", line 301, in get_reduced_index
#         new_records = SubdirData.query_all(spec, channels=channels, subdirs=subdirs,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 115, in query_all
#         create_cache_dir()
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 737, in create_cache_dir
#         cache_dir = join(PackageCacheData.first_writable().pkgs_dir, 'cache')
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\package_cache_data.py", line 158, in first_writable
#         pkgs_dirs = context.pkgs_dirs
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\base\context.py", line 555, in pkgs_dirs
#         fixed_dirs += user_data_dir(APP_NAME, APP_NAME),
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 67, in user_data_dir
#         path = os.path.join(_get_win_folder(const), appauthor, appname)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 265, in _get_win_folder_with_pywin32
#         from win32com.shell import shellcon, shell
#     ImportError: DLL load failed while importing shell: 지정된 프로시저를 찾을 수 없습니다.
#
# `$ c:\Users\qnwje\anaconda3\Scripts\conda-script.py install -y -c conda-forge wordcloud`
#
#   environment variables:
# conda info could not be constructed.
# KeyError('pkgs_dirs')
#
# An unexpected error has occurred. Conda has prepared the above report.
# Collecting package metadata (current_repodata.json): ...working... failed
# WARNING conda.exceptions:print_unexpected_error_report(1251): KeyError('pkgs_dirs')
# Traceback (most recent call last):
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\exceptions.py", line 1129, in __call__
#     return func(*args, **kwargs)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main.py", line 86, in main_subshell
#     exit_code = do_call(args, p)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\conda_argparse.py", line 93, in do_call
#     return getattr(module, func_name)(args, parser)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\notices\core.py", line 72, in wrapper
#     return_value = func(*args, **kwargs)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main_install.py", line 22, in execute
#     install(args, parser, 'install')
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\install.py", line 261, in install
#     unlink_link_transaction = solver.solve_for_transaction(
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 156, in solve_for_transaction
#     unlink_precs, link_precs = self.solve_for_diff(update_modifier, deps_modifier,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 199, in solve_for_diff
#     final_precs = self.solve_final_state(update_modifier, deps_modifier, prune, ignore_pinned,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 304, in solve_final_state
#     ssc = self._collect_all_metadata(ssc)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\common\io.py", line 86, in decorated
#     return f(*args, **kwds)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 467, in _collect_all_metadata
#     index, r = self._prepare(prepared_specs)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 1061, in _prepare
#     reduced_index = get_reduced_index(self.prefix, self.channels,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\index.py", line 301, in get_reduced_index
#     new_records = SubdirData.query_all(spec, channels=channels, subdirs=subdirs,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 115, in query_all
#     create_cache_dir()
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 737, in create_cache_dir
#     cache_dir = join(PackageCacheData.first_writable().pkgs_dir, 'cache')
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\package_cache_data.py", line 158, in first_writable
#     pkgs_dirs = context.pkgs_dirs
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\base\context.py", line 555, in pkgs_dirs
#     fixed_dirs += user_data_dir(APP_NAME, APP_NAME),
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 67, in user_data_dir
#     path = os.path.join(_get_win_folder(const), appauthor, appname)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 265, in _get_win_folder_with_pywin32
#     from win32com.shell import shellcon, shell
# ImportError: DLL load failed while importing shell: 지정된 프로시저를 찾을 수 없습니다.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\exceptions.py", line 1249, in print_unexpected_error_report
#     message_builder.append(get_main_info_str(error_report['conda_info']))
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main_info.py", line 237, in get_main_info_str
#     info_dict['_' + key] = ('\n' + 26 * ' ').join(info_dict[key])
# KeyError: 'pkgs_dirs'
#
# # >>>>>>>>>>>>>>>>>>>>>> ERROR REPORT <<<<<<<<<<<<<<<<<<<<<<
#
#     Traceback (most recent call last):
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\exceptions.py", line 1129, in __call__
#         return func(*args, **kwargs)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main.py", line 86, in main_subshell
#         exit_code = do_call(args, p)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\conda_argparse.py", line 93, in do_call
#         return getattr(module, func_name)(args, parser)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\notices\core.py", line 72, in wrapper
#         return_value = func(*args, **kwargs)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main_install.py", line 22, in execute
#         install(args, parser, 'install')
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\install.py", line 261, in install
#         unlink_link_transaction = solver.solve_for_transaction(
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 156, in solve_for_transaction
#         unlink_precs, link_precs = self.solve_for_diff(update_modifier, deps_modifier,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 199, in solve_for_diff
#         final_precs = self.solve_final_state(update_modifier, deps_modifier, prune, ignore_pinned,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 304, in solve_final_state
#         ssc = self._collect_all_metadata(ssc)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\common\io.py", line 86, in decorated
#         return f(*args, **kwds)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 467, in _collect_all_metadata
#         index, r = self._prepare(prepared_specs)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 1061, in _prepare
#         reduced_index = get_reduced_index(self.prefix, self.channels,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\index.py", line 301, in get_reduced_index
#         new_records = SubdirData.query_all(spec, channels=channels, subdirs=subdirs,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 115, in query_all
#         create_cache_dir()
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 737, in create_cache_dir
#         cache_dir = join(PackageCacheData.first_writable().pkgs_dir, 'cache')
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\package_cache_data.py", line 158, in first_writable
#         pkgs_dirs = context.pkgs_dirs
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\base\context.py", line 555, in pkgs_dirs
#         fixed_dirs += user_data_dir(APP_NAME, APP_NAME),
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 67, in user_data_dir
#         path = os.path.join(_get_win_folder(const), appauthor, appname)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 265, in _get_win_folder_with_pywin32
#         from win32com.shell import shellcon, shell
#     ImportError: DLL load failed while importing shell: 지정된 프로시저를 찾을 수 없습니다.
#
# `$ c:\Users\qnwje\anaconda3\Scripts\conda-script.py install -y nltk`
#
#   environment variables:
# conda info could not be constructed.
# KeyError('pkgs_dirs')
#
# An unexpected error has occurred. Conda has prepared the above report.
# Collecting package metadata (current_repodata.json): ...working... failed
# WARNING conda.exceptions:print_unexpected_error_report(1251): KeyError('pkgs_dirs')
# Traceback (most recent call last):
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\exceptions.py", line 1129, in __call__
#     return func(*args, **kwargs)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main.py", line 86, in main_subshell
#     exit_code = do_call(args, p)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\conda_argparse.py", line 93, in do_call
#     return getattr(module, func_name)(args, parser)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\notices\core.py", line 72, in wrapper
#     return_value = func(*args, **kwargs)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main_install.py", line 22, in execute
#     install(args, parser, 'install')
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\install.py", line 261, in install
#     unlink_link_transaction = solver.solve_for_transaction(
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 156, in solve_for_transaction
#     unlink_precs, link_precs = self.solve_for_diff(update_modifier, deps_modifier,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 199, in solve_for_diff
#     final_precs = self.solve_final_state(update_modifier, deps_modifier, prune, ignore_pinned,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 304, in solve_final_state
#     ssc = self._collect_all_metadata(ssc)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\common\io.py", line 86, in decorated
#     return f(*args, **kwds)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 467, in _collect_all_metadata
#     index, r = self._prepare(prepared_specs)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 1061, in _prepare
#     reduced_index = get_reduced_index(self.prefix, self.channels,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\index.py", line 301, in get_reduced_index
#     new_records = SubdirData.query_all(spec, channels=channels, subdirs=subdirs,
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 115, in query_all
#     create_cache_dir()
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 737, in create_cache_dir
#     cache_dir = join(PackageCacheData.first_writable().pkgs_dir, 'cache')
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\package_cache_data.py", line 158, in first_writable
#     pkgs_dirs = context.pkgs_dirs
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\base\context.py", line 555, in pkgs_dirs
#     fixed_dirs += user_data_dir(APP_NAME, APP_NAME),
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 67, in user_data_dir
#     path = os.path.join(_get_win_folder(const), appauthor, appname)
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 265, in _get_win_folder_with_pywin32
#     from win32com.shell import shellcon, shell
# ImportError: DLL load failed while importing shell: 지정된 프로시저를 찾을 수 없습니다.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\exceptions.py", line 1249, in print_unexpected_error_report
#     message_builder.append(get_main_info_str(error_report['conda_info']))
#   File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main_info.py", line 237, in get_main_info_str
#     info_dict['_' + key] = ('\n' + 26 * ' ').join(info_dict[key])
# KeyError: 'pkgs_dirs'
#
# # >>>>>>>>>>>>>>>>>>>>>> ERROR REPORT <<<<<<<<<<<<<<<<<<<<<<
#
#     Traceback (most recent call last):
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\exceptions.py", line 1129, in __call__
#         return func(*args, **kwargs)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main.py", line 86, in main_subshell
#         exit_code = do_call(args, p)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\conda_argparse.py", line 93, in do_call
#         return getattr(module, func_name)(args, parser)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\notices\core.py", line 72, in wrapper
#         return_value = func(*args, **kwargs)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\main_install.py", line 22, in execute
#         install(args, parser, 'install')
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\cli\install.py", line 261, in install
#         unlink_link_transaction = solver.solve_for_transaction(
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 156, in solve_for_transaction
#         unlink_precs, link_precs = self.solve_for_diff(update_modifier, deps_modifier,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 199, in solve_for_diff
#         final_precs = self.solve_final_state(update_modifier, deps_modifier, prune, ignore_pinned,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 304, in solve_final_state
#         ssc = self._collect_all_metadata(ssc)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\common\io.py", line 86, in decorated
#         return f(*args, **kwds)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 467, in _collect_all_metadata
#         index, r = self._prepare(prepared_specs)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\solve.py", line 1061, in _prepare
#         reduced_index = get_reduced_index(self.prefix, self.channels,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\index.py", line 301, in get_reduced_index
#         new_records = SubdirData.query_all(spec, channels=channels, subdirs=subdirs,
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 115, in query_all
#         create_cache_dir()
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\subdir_data.py", line 737, in create_cache_dir
#         cache_dir = join(PackageCacheData.first_writable().pkgs_dir, 'cache')
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\core\package_cache_data.py", line 158, in first_writable
#         pkgs_dirs = context.pkgs_dirs
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\base\context.py", line 555, in pkgs_dirs
#         fixed_dirs += user_data_dir(APP_NAME, APP_NAME),
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 67, in user_data_dir
#         path = os.path.join(_get_win_folder(const), appauthor, appname)
#       File "c:\Users\qnwje\anaconda3\lib\site-packages\conda\_vendor\appdirs.py", line 265, in _get_win_folder_with_pywin32
#         from win32com.shell import shellcon, shell
#     ImportError: DLL load failed while importing shell: 지정된 프로시저를 찾을 수 없습니다.
#
# `$ c:\Users\qnwje\anaconda3\Scripts\conda-script.py install -y scikit-learn`
#
#   environment variables:
# conda info could not be constructed.
# KeyError('pkgs_dirs')
#
# An unexpected error has occurred. Conda has prepared the above report.

# %%
import nltk

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import jpype

jpype.__version__
# Out:
# '1.4.1'

# %%
from konlpy.tag import Okt

t = Okt()
# Out:
# ---------------------------------------------------------------------------
# JVMNotFoundException                      Traceback (most recent call last)
# c:\Users\qnwje\OneDrive\바탕 화면\zerobase\제로베이스_강의\머신러닝\08.NLP.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/qnwje/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/zerobase/%EC%A0%9C%EB%A1%9C%EB%B2%A0%EC%9D%B4%EC%8A%A4_%EA%B0%95%EC%9D%98/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D/08.NLP.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> from konlpy.tag import Okt
# ----> <a href='vscode-notebook-cell:/c%3A/Users/qnwje/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/zerobase/%EC%A0%9C%EB%A1%9C%EB%B2%A0%EC%9D%B4%EC%8A%A4_%EA%B0%95%EC%9D%98/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D/08.NLP.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> t = Okt()
#
# File c:\Users\qnwje\anaconda3\lib\site-packages\konlpy\tag\_okt.py:51, in Okt.__init__(self, jvmpath, max_heap_size)
#      49 def __init__(self, jvmpath=None, max_heap_size=1024):
#      50     if not jpype.isJVMStarted():
# ---> 51         jvm.init_jvm(jvmpath, max_heap_size)
#      53     oktJavaPackage = jpype.JPackage('kr.lucypark.okt')
#      54     OktInterfaceJavaClass = oktJavaPackage.OktInterface
#
# File c:\Users\qnwje\anaconda3\lib\site-packages\konlpy\jvm.py:55, in init_jvm(jvmpath, max_heap_size)
#      52 args = [javadir, os.sep]
#      53 classpath = [f.format(*args) for f in folder_suffix]
# ---> 55 jvmpath = jvmpath or jpype.getDefaultJVMPath()
#      57 # NOTE: Temporary patch for Issue #76. Erase when possible.
#      58 if sys.platform == 'darwin'\
#      59         and jvmpath.find('1.8.0') > 0\
#      60         and jvmpath.endswith('libjvm.dylib'):
#
# File c:\Users\qnwje\anaconda3\lib\site-packages\jpype\_jvmfinder.py:74, in getDefaultJVMPath()
#      72 else:
#      73     finder = LinuxJVMFinder()
# ---> 74 return finder.get_jvm_path()
#
# File c:\Users\qnwje\anaconda3\lib\site-packages\jpype\_jvmfinder.py:212, in JVMFinder.get_jvm_path(self)
#     210 if jvm_notsupport_ext is not None:
#     211     raise jvm_notsupport_ext
# --> 212 raise JVMNotFoundException("No JVM shared library file ({0}) "
#     213                            "found. Try setting up the JAVA_HOME "
#     214                            "environment variable properly."
#     215                            .format(self._libfile))
#
# JVMNotFoundException: No JVM shared library file (jvm.dll) found. Try setting up the JAVA_HOME environment variable properly.

# %%
import tweepy

tweepy.__version__
# Out:
# '3.10.0'
